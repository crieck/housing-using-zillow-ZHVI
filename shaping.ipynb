# %%
#here I alsmost got geopandas working

import geopandas

# %%
df=geopandas.read_file('documents/homeworkarchive/p3d/City_Boundaries_in_Minnesota.shp')

# %%
df.crs
# Out:
# {u'init': u'epsg:26915'}

# %%
df.describe()
# Out:
#          GNIS_FEATU     COUNTY_GNI  COUNTY_COD     POPULATION     SHAPE_Leng  \
# count  8.980000e+02     898.000000  898.000000     898.000000     898.000000
# mean   2.372179e+06  659615.062361   44.899777    5051.802895   17270.533008
# std    1.988294e+05     645.548023   25.411726   20156.278177   17947.882876
# min    6.637720e+05  659447.000000    1.000000       0.000000     723.808150
# 25%    2.394298e+06  659468.250000   23.000000     195.000000    6424.653927
# 50%    2.395222e+06  659492.000000   46.500000     651.000000   10442.050237
# 75%    2.396081e+06  659513.000000   67.000000    2623.250000   21775.122772
# max    2.437910e+06  663198.000000   87.000000  412517.000000  191315.020169
#
#          SHAPE_Area
# count  8.980000e+02
# mean   1.350706e+07
# std    3.099747e+07
# min    2.255044e+04
# 25%    1.544530e+06
# 50%    3.258548e+06
# 75%    8.716871e+06
# max    4.823371e+08

# %%
df.to_file('shapefile.geojson', driver="GeoJSON")
# Out:
# /anaconda3/lib/python2.7/site-packages/geopandas/io/file.py:108: FionaDeprecationWarning: Use fiona.Env() instead.
#   with fiona.drivers():
# ---------------------------------------------------------------------------
# GeometryTypeValidationError               Traceback (most recent call last)
# <ipython-input-4-ad90394b3bc4> in <module>()
# ----> 1 df.to_file('shapefile.geojson', driver="GeoJSON")
#
# /anaconda3/lib/python2.7/site-packages/geopandas/geodataframe.pyc in to_file(self, filename, driver, schema, **kwargs)
#     411         """
#     412         from geopandas.io.file import to_file
# --> 413         to_file(self, filename, driver, schema, **kwargs)
#     414
#     415     def to_crs(self, crs=None, epsg=None, inplace=False):
#
# /anaconda3/lib/python2.7/site-packages/geopandas/io/file.pyc in to_file(df, filename, driver, schema, **kwargs)
#     109         with fiona.open(filename, 'w', driver=driver, crs=df.crs,
# ...

# %%
df2=geopandas.read_file('shapefile.geojson')

# %%
df2.describe()
# Out:
#          GNIS_FEATU    COUNTY_GNI  COUNTY_COD  POPULATION    SHAPE_Leng  \
# count  5.000000e+00       5.00000    5.000000    5.000000      5.000000
# mean   2.396572e+06  659491.80000   47.000000  298.800000   8153.758206
# std    8.159037e+02      22.79693   23.151674  289.569853   3058.954369
# min    2.395247e+06  659469.00000   24.000000   50.000000   5065.139661
# 25%    2.396313e+06  659471.00000   26.000000   68.000000   5483.220018
# 50%    2.397072e+06  659494.00000   49.000000  150.000000   8122.154915
# 75%    2.397101e+06  659501.00000   56.000000  595.000000   9636.690167
# max    2.397129e+06  659524.00000   80.000000  631.000000  12461.586269
#
#          SHAPE_Area
# count  5.000000e+00
# mean   2.991627e+06
# std    1.616278e+06
# min    1.315488e+06
# 25%    1.731398e+06
# 50%    2.672616e+06
# 75%    4.048669e+06
# max    5.189964e+06

# %%
dfd = pd.read_sql_query("select * from MedianValue;", conn)
dfd.head()
# Out:
#    index   RegionName  1996-04  1996-05  1996-06  1996-07  1996-08  1996-09  \
# 0     46  Minneapolis     69.0     69.0     69.0     69.0     70.0     70.0
# 1     73   Saint Paul     65.0     66.0     66.0     65.0     65.0     65.0
# 2    288    Rochester     82.0     82.0     83.0     83.0     84.0     84.0
# 3    438       Duluth     61.0     63.0     64.0     66.0     67.0     68.0
# 4    488  Bloomington     93.0     93.0     93.0     94.0     94.0     95.0
#
#    1996-10  1996-11  ...  2018-05  2018-06  2018-07  2018-08  2018-09  \
# 0     70.0     70.0  ...      230      230      230      230      230
# 1     65.0     65.0  ...      183      183      183      183      183
# 2     85.0     85.0  ...      195      197      197      197      198
# 3     69.0     69.0  ...      182      183      184      185      185
# 4     95.0     95.0  ...      211      210      211      211      212
#
#    2018-10  2018-11  2018-12  2019-01  2019-02
# ...

# %%
df4 = df.merge(dfd, on=['RegionName'])
df4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-a5237540b3c4> in <module>()
# ----> 1 df4 = df.merge(dfd, on=['RegionName'])
#       2 df4
#
# /anaconda3/lib/python2.7/site-packages/geopandas/geodataframe.pyc in merge(self, *args, **kwargs)
#     473
#     474     def merge(self, *args, **kwargs):
# --> 475         result = DataFrame.merge(self, *args, **kwargs)
#     476         geo_col = self._geometry_column_name
#     477         if isinstance(result, DataFrame) and geo_col in result:
#
# /anaconda3/lib/python2.7/site-packages/pandas/core/frame.pyc in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# ...

# %%
df2.groupby('RegionName')['RegionName'].nunique()
# Out:
# RegionName
# Norcross      1
# Randall       1
# Twin Lakes    1
# Urbank        1
# Verndale      1
# Name: RegionName, dtype: int64
