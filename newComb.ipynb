# %%
#here things really started to come together.  I was super stoked.  However, after getting our geojson
#together we couldnt get the file to load on our html - assumed it was too big



import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import geopandas
import matplotlib.pyplot as plt
import sqlite3
import fiona

# %%
sdf=geopandas.read_file('documents/pd3.2/ZillowNeighborhoods-MN/ZillowNeighborhoods-MN.shp')

# %%
conn = sqlite3.connect('documents/homeworkarchive/p3d/zdat.sqlite')
c = conn.cursor()
vdf = pd.read_sql_query("select * from MedianValue;", conn)

# %%
sdf.head()
# Out:
#   State  County          City           Name RegionID  \
# 0    MN  Dakota  Apple Valley    Johnny Cake   762860
# 1    MN  Dakota  Apple Valley  Lebanon Hills   762876
# 2    MN  Dakota  Apple Valley      Alimagnet   762878
# 3    MN  Dakota  Apple Valley            Zoo   762877
# 4    MN  Dakota  Apple Valley        Redwood   197444
#
#                                             geometry
# 0  POLYGON ((-93.17725967499996 44.73189202300006...
# 1  POLYGON ((-93.15606 44.768049, -93.16657555699...
# 2  POLYGON ((-93.220367 44.776255, -93.2198652119...
# 3  POLYGON ((-93.187015 44.776104, -93.1869399359...
# 4  POLYGON ((-93.23308244399999 44.73912014600006...

# %%
sdf2=sdf[['County','City','RegionID','geometry']]

# %%
vdf=vdf.drop(['index'], axis=1)

# %%
vdf.head()
# Out:
#    RegionID   RegionName  1996-04  1996-05  1996-06  1996-07  1996-08  \
# 0      5983  Minneapolis     69.0     69.0     69.0     69.0     70.0
# 1     20313   Saint Paul     65.0     66.0     66.0     65.0     65.0
# 2     26791    Rochester     82.0     82.0     83.0     83.0     84.0
# 3     51758       Duluth     61.0     63.0     64.0     66.0     67.0
# 4     10451  Bloomington     93.0     93.0     93.0     94.0     94.0
#
#    1996-09  1996-10  1996-11  ...  2018-05  2018-06  2018-07  2018-08  \
# 0     70.0     70.0     70.0  ...      230      230      230      230
# 1     65.0     65.0     65.0  ...      183      183      183      183
# 2     84.0     85.0     85.0  ...      195      197      197      197
# 3     68.0     69.0     69.0  ...      182      183      184      185
# 4     95.0     95.0     95.0  ...      211      210      211      211
#
#    2018-09  2018-10  2018-11  2018-12  2019-01  2019-02
# 0      230      231      232      233      234      234
# ...

# %%
vdf.describe()
# Out:
#             RegionID     1996-04     1996-05     1996-06     1996-07  \
# count     337.000000  315.000000  315.000000  315.000000  315.000000
# mean    32821.083086   61.844444   61.977778   62.139683   62.215873
# std     29485.977374   23.927530   23.940135   24.004104   23.950009
# min      3425.000000   20.000000   20.000000   20.000000   20.000000
# 25%     16542.000000   41.000000   41.000000   41.000000   41.000000
# 50%     30929.000000   63.000000   63.000000   64.000000   64.000000
# 75%     44544.000000   80.500000   81.000000   81.000000   81.000000
# max    397862.000000  129.000000  128.000000  128.000000  128.000000
#
#           1996-08     1996-09     1996-10     1996-11     1996-12  ...  \
# count  315.000000  315.000000  315.000000  315.000000  315.000000  ...
# mean    62.266667   62.311111   62.495238   62.657143   62.901587  ...
# std     24.026763   24.103777   24.147948   24.205790   24.264988  ...
# ...

# %%
sdf2.describe()
# Out:
#           County         City RegionID  \
# count        291          291      291
# unique         8            9      290
# top     Hennepin  Minneapolis   764300
# freq         198           86        2
#
#                                                  geometry
# count                                                 291
# unique                                                290
# top     POLYGON ((-94.13162270099997 45.55661306400003...
# freq                                                    2

# %%
sdf2=sdf2["RegionID"] = pd.to_numeric(sdf2["RegionID"])

# %%
cdf=pd.merge(sdf, vdf, on='RegionID', how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-24126e58c5b1> in <module>()
# ----> 1 cdf=pd.merge(sdf, vdf, on='RegionID', how='left')
#
# /anaconda3/lib/python2.7/site-packages/pandas/core/reshape/merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# /anaconda3/lib/python2.7/site-packages/pandas/core/reshape/merge.pyc in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     531         # validate the merge keys dtypes. We may need to coerce
# ...

# %%
000709687
